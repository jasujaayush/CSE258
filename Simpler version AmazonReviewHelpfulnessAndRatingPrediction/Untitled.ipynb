# %%
import numpy
import pathlib
import urllib
import scipy.optimize
import random

def parseData(fname):
    url = pathlib.Path(fname).as_uri()
    for l in urllib.request.urlopen(url):
        yield eval(l)

#print "Reading data..."
data = list(parseData("/home/ayush/cse258/hw3/train.json"))
#print "done"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-ec45e679d50a> in <module>()
#      11
#      12 #print "Reading data..."
# ---> 13 data = list(parseData("/home/ayush/cse258/hw3/train.json"))
#      14 #print "done"
#
# <ipython-input-1-ec45e679d50a> in parseData(fname)
#       7 def parseData(fname):
#       8     url = pathlib.Path(fname).as_uri()
# ----> 9     for l in urllib.request.urlopen(url):
#      10         yield eval(l)
#      11
#
# AttributeError: module 'urllib' has no attribute 'request'

# %%
data
# Out:
# [123,
#  39,
#  99,
#  97,
#  116,
#  101,
#  103,
#  111,
#  114,
#  121,
#  73,
#  68,
#  39,
#  58,
#  32,
#  48,
#  44,
#  32,
#  39,
#  99,
#  97,
#  116,
#  101,
#  103,
#  111,
#  114,
#  105,
#  101,
#  115,
#  39,
#  58,
#  32,
#  91,
#  91,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  44,
#  32,
#  83,
#  104,
#  111,
#  101,
#  115,
#  32,
#  38,
#  32,
#  74,
#  101,
#  119,
#  101,
#  108,
#  114,
#  121,
#  39,
#  44,
#  32,
#  39,
#  87,
#  111,
#  109,
#  101,
#  110,
#  39,
#  93,
#  44,
#  32,
#  91,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  44,
#  32,
#  83,
#  104,
#  111,
#  101,
#  115,
#  32,
#  38,
#  32,
#  74,
#  101,
#  119,
#  101,
#  108,
#  114,
#  121,
#  39,
#  44,
#  32,
#  39,
#  78,
#  111,
#  118,
#  101,
#  108,
#  116,
#  121,
#  44,
#  32,
#  67,
#  111,
#  115,
#  116,
#  117,
#  109,
#  101,
#  115,
#  32,
#  38,
#  32,
#  77,
#  111,
#  114,
#  101,
#  39,
#  44,
#  32,
#  39,
#  78,
#  111,
#  118,
#  101,
#  108,
#  116,
#  121,
#  39,
#  44,
#  32,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  39,
#  44,
#  32,
#  39,
#  87,
#  111,
#  109,
#  101,
#  110,
#  39,
#  44,
#  32,
#  39,
#  76,
#  101,
#  103,
#  103,
#  105,
#  110,
#  103,
#  115,
#  39,
#  93,
#  93,
#  44,
#  32,
#  39,
#  105,
#  116,
#  101,
#  109,
#  73,
#  68,
#  39,
#  58,
#  32,
#  39,
#  73,
#  54,
#  53,
#  53,
#  51,
#  53,
#  53,
#  51,
#  50,
#  56,
#  39,
#  44,
#  32,
#  39,
#  114,
#  101,
#  118,
#  105,
#  101,
#  119,
#  101,
#  114,
#  73,
#  68,
#  39,
#  58,
#  32,
#  39,
#  85,
#  55,
#  52,
#  53,
#  56,
#  56,
#  49,
#  48,
#  51,
#  56,
#  39,
#  44,
#  32,
#  39,
#  114,
#  97,
#  116,
#  105,
#  110,
#  103,
#  39,
#  58,
#  32,
#  51,
#  46,
#  48,
#  44,
#  32,
#  39,
#  114,
#  101,
#  118,
#  105,
#  101,
#  119,
#  84,
#  101,
#  120,
#  116,
#  39,
#  58,
#  32,
#  39,
#  84,
#  104,
#  101,
#  115,
#  101,
#  32,
#  97,
#  114,
#  101,
#  32,
#  99,
#  117,
#  116,
#  101,
#  44,
#  32,
#  98,
#  117,
#  116,
#  32,
#  116,
#  104,
#  101,
#  121,
#  32,
#  97,
#  114,
#  101,
#  32,
#  97,
#  32,
#  108,
#  105,
#  116,
#  116,
#  108,
#  101,
#  32,
#  115,
#  109,
#  97,
#  108,
#  108,
#  46,
#  32,
#  32,
#  87,
#  104,
#  101,
#  110,
#  32,
#  73,
#  32,
#  112,
#  117,
#  116,
#  32,
#  116,
#  104,
#  101,
#  109,
#  32,
#  111,
#  110,
#  44,
#  32,
#  109,
#  121,
#  32,
#  108,
#  101,
#  103,
#  115,
#  32,
#  115,
#  116,
#  114,
#  101,
#  116,
#  99,
#  104,
#  32,
#  116,
#  104,
#  101,
#  32,
#  102,
#  97,
#  98,
#  114,
#  105,
#  99,
#  32,
#  109,
#  97,
#  107,
#  105,
#  110,
#  103,
#  32,
#  116,
#  104,
#  101,
#  32,
#  98,
#  108,
#  97,
#  99,
#  107,
#  32,
#  102,
#  97,
#  100,
#  101,
#  32,
#  111,
#  117,
#  116,
#  46,
#  39,
#  44,
#  32,
#  39,
#  114,
#  101,
#  118,
#  105,
#  101,
#  119,
#  72,
#  97,
#  115,
#  104,
#  39,
#  58,
#  32,
#  39,
#  82,
#  49,
#  49,
#  53,
#  49,
#  54,
#  48,
#  54,
#  55,
#  48,
#  39,
#  44,
#  32,
#  39,
#  114,
#  101,
#  118,
#  105,
#  101,
#  119,
#  84,
#  105,
#  109,
#  101,
#  39,
#  58,
#  32,
#  39,
#  48,
#  53,
#  32,
#  50,
#  48,
#  44,
#  32,
#  50,
#  48,
#  49,
#  52,
#  39,
#  44,
#  32,
#  39,
#  115,
#  117,
#  109,
#  109,
#  97,
#  114,
#  121,
#  39,
#  58,
#  32,
#  39,
#  67,
#  117,
#  116,
#  101,
#  39,
#  44,
#  32,
#  39,
#  117,
#  110,
#  105,
#  120,
#  82,
#  101,
#  118,
#  105,
#  101,
#  119,
#  84,
#  105,
#  109,
#  101,
#  39,
#  58,
#  32,
#  49,
#  52,
#  48,
#  48,
#  53,
#  52,
#  52,
#  48,
#  48,
#  48,
#  44,
#  32,
#  39,
#  104,
#  101,
#  108,
#  112,
#  102,
#  117,
#  108,
#  39,
#  58,
#  32,
#  123,
#  39,
#  111,
#  117,
#  116,
#  79,
#  102,
#  39,
#  58,
#  32,
#  48,
#  44,
#  32,
#  39,
#  110,
#  72,
#  101,
#  108,
#  112,
#  102,
#  117,
#  108,
#  39,
#  58,
#  32,
#  48,
#  125,
#  125,
#  10,
#  123,
#  39,
#  99,
#  97,
#  116,
#  101,
#  103,
#  111,
#  114,
#  121,
#  73,
#  68,
#  39,
#  58,
#  32,
#  48,
#  44,
#  32,
#  39,
#  99,
#  97,
#  116,
#  101,
#  103,
#  111,
#  114,
#  105,
#  101,
#  115,
#  39,
#  58,
#  32,
#  91,
#  91,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  44,
#  32,
#  83,
#  104,
#  111,
#  101,
#  115,
#  32,
#  38,
#  32,
#  74,
#  101,
#  119,
#  101,
#  108,
#  114,
#  121,
#  39,
#  44,
#  32,
#  39,
#  87,
#  111,
#  109,
#  101,
#  110,
#  39,
#  44,
#  32,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  39,
#  44,
#  32,
#  39,
#  76,
#  105,
#  110,
#  103,
#  101,
#  114,
#  105,
#  101,
#  44,
#  32,
#  83,
#  108,
#  101,
#  101,
#  112,
#  32,
#  38,
#  32,
#  76,
#  111,
#  117,
#  110,
#  103,
#  101,
#  39,
#  44,
#  32,
#  39,
#  73,
#  110,
#  116,
#  105,
#  109,
#  97,
#  116,
#  101,
#  115,
#  39,
#  44,
#  32,
#  39,
#  66,
#  114,
#  97,
#  115,
#  39,
#  44,
#  32,
#  39,
#  69,
#  118,
#  101,
#  114,
#  121,
#  100,
#  97,
#  121,
#  32,
#  66,
#  114,
#  97,
#  115,
#  39,
#  93,
#  44,
#  32,
#  91,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  44,
#  32,
#  83,
#  104,
#  111,
#  101,
#  115,
#  32,
#  38,
#  32,
#  74,
#  101,
#  119,
#  101,
#  108,
#  114,
#  121,
#  39,
#  44,
#  32,
#  39,
#  87,
#  111,
#  109,
#  101,
#  110,
#  39,
#  44,
#  32,
#  39,
#  80,
#  101,
#  116,
#  105,
#  116,
#  101,
#  39,
#  44,
#  32,
#  39,
#  73,
#  110,
#  116,
#  105,
#  109,
#  97,
#  116,
#  101,
#  115,
#  39,
#  44,
#  32,
#  39,
#  66,
#  114,
#  97,
#  115,
#  39,
#  44,
#  32,
#  39,
#  69,
#  118,
#  101,
#  114,
#  121,
#  100,
#  97,
#  121,
#  32,
#  66,
#  114,
#  97,
#  115,
#  39,
#  93,
#  93,
#  44,
#  32,
#  39,
#  105,
#  116,
#  101,
#  109,
#  73,
#  68,
#  39,
#  58,
#  32,
#  39,
#  73,
#  50,
#  52,
#  49,
#  48,
#  57,
#  50,
#  51,
#  49,
#  52,
#  39,
#  44,
#  32,
#  39,
#  114,
#  101,
#  118,
#  105,
#  101,
#  119,
#  101,
#  114,
#  73,
#  68,
#  39,
#  58,
#  32,
#  39,
#  85,
#  48,
#  50,
#  51,
#  53,
#  55,
#  55,
#  52,
#  48,
#  53,
#  39,
#  44,
#  32,
#  39,
#  114,
#  97,
#  116,
#  105,
#  110,
#  103,
#  39,
#  58,
#  32,
#  52,
#  46,
#  48,
#  44,
#  32,
#  39,
#  114,
#  101,
#  118,
#  105,
#  101,
#  119,
#  84,
#  101,
#  120,
#  116,
#  39,
#  58,
#  32,
#  39,
#  73,
#  32,
#  108,
#  111,
#  118,
#  101,
#  32,
#  116,
#  104,
#  101,
#  32,
#  108,
#  111,
#  111,
#  107,
#  32,
#  111,
#  102,
#  32,
#  116,
#  104,
#  105,
#  115,
#  32,
#  98,
#  114,
#  97,
#  44,
#  32,
#  105,
#  116,
#  32,
#  105,
#  115,
#  32,
#  119,
#  104,
#  97,
#  116,
#  32,
#  73,
#  32,
#  119,
#  97,
#  110,
#  116,
#  101,
#  100,
#  44,
#  32,
#  104,
#  111,
#  119,
#  101,
#  118,
#  101,
#  114,
#  44,
#  32,
#  105,
#  116,
#  32,
#  105,
#  115,
#  32,
#  97,
#  98,
#  111,
#  117,
#  116,
#  32,
#  97,
#  32,
#  99,
#  117,
#  112,
#  32,
#  115,
#  105,
#  122,
#  101,
#  32,
#  65,
#  78,
#  68,
#  32,
#  98,
#  97,
#  110,
#  100,
#  32,
#  115,
#  105,
#  122,
#  101,
#  32,
#  116,
#  111,
#  111,
#  32,
#  115,
#  109,
#  97,
#  108,
#  108,
#  46,
#  32,
#  84,
#  104,
#  101,
#  32,
#  99,
#  117,
#  112,
#  115,
#  32,
#  97,
#  114,
#  101,
#  32,
#  115,
#  104,
#  101,
#  101,
#  114,
#  44,
#  32,
#  119,
#  104,
#  105,
#  99,
#  104,
#  32,
#  105,
#  115,
#  32,
#  119,
#  104,
#  97,
#  116,
#  32,
#  73,
#  32,
#  119,
#  97,
#  110,
#  116,
#  101,
#  100,
#  32,
#  97,
#  ...]

# %%
d
