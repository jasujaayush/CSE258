# %%
import numpy
import pathlib
from urllib.request import urlopen
import scipy.optimize
import random

def parseData(fname):
    url = pathlib.Path(fname).as_uri()
    for l in urllib.request.urlopen(url).read():
        yield l

#print "Reading data..."
data = list(parseData("/home/ayush/cse258/hw3/train.json"))
#print "done"
# Out:
# {'categoryID': 0, 'categories': [['Clothing, Shoes & Jewelry', 'Women'], ['Clothing, Shoes & Jewelry', 'Novelty, Costumes & More', 'Novelty', 'Clothing', 'Women', 'Leggings']], 'itemID': 'I655355328', 'reviewerID': 'U745881038', 'rating': 3.0, 'reviewText': 'These are cute, but they are a little small.  When I put them on, my legs stretch the fabric making the black fade out.', 'reviewHash': 'R115160670', 'reviewTime': '05 20, 2014', 'summary': 'Cute', 'unixReviewTime': 1400544000, 'helpful': {'outOf': 0, 'nHelpful': 0}}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-09435710a640> in <module>()
#      17
#      18 #print "Reading data..."
# ---> 19 data = list(parseData("train.json"))
#      20 #print "done"
#
# <ipython-input-54-09435710a640> in parseData(fname)
#      10         for line in f:
#      11             print(line)
# ...

# %%
data
# Out:
# [123,
#  39,
#  99,
#  97,
#  116,
#  101,
#  103,
#  111,
#  114,
#  121,
#  73,
#  68,
#  39,
#  58,
#  32,
#  48,
#  44,
#  32,
#  39,
#  99,
#  97,
#  116,
#  101,
#  103,
#  111,
#  114,
#  105,
#  101,
#  115,
#  39,
#  58,
#  32,
#  91,
#  91,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  44,
#  32,
#  83,
#  104,
#  111,
#  101,
#  115,
#  32,
#  38,
#  32,
#  74,
#  101,
#  119,
#  101,
#  108,
#  114,
#  121,
#  39,
#  44,
#  32,
#  39,
#  87,
#  111,
#  109,
#  101,
#  110,
#  39,
#  93,
#  44,
#  32,
#  91,
#  39,
#  67,
#  108,
#  111,
#  116,
#  104,
#  105,
#  110,
#  103,
#  44,
#  32,
#  83,
#  104,
#  111,
#  101,
#  115,
#  32,
#  38,
#  32,
#  74,
#  101,
#  119,
#  101,
#  108,
#  114,
#  121,
#  39,
#  44,
#  32,
#  39,
#  78,
#  111,
#  118,
#  101,
#  108,
#  116,
#  121,
#  44,
#  32,
#  67,
#  111,
#  115,
#  116,
#  117,
#  109,
#  101,
#  115,
#  32,
#  38,
#  32,
#  77,
#  111,
#  114,
#  101,
#  39,
#  44,
#  32,
#  39,
#  78,
# ...

# %%
d
